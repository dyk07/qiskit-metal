# %%
from qiskit_metal.toolbox_metal.design_dsl import build_design

# %%
design = build_design("./2x2_4qubit.metal.yaml")
# Out:
# 03:57AM 40s WARNING [check_lengths]: For path table, component=top_bus, key=trace has short segments that could cause issues with fillet. Values in (17-18)  are index(es) in shapely geometry.
# 03:57AM 40s WARNING [check_lengths]: For path table, component=top_bus, key=cut has short segments that could cause issues with fillet. Values in (17-18)  are index(es) in shapely geometry.

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs

# %%
gui = MetalGUI(design)
